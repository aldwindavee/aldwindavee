# %%
import os #Set Working Directory for saving files
print(os.getcwd()) #Current working directory
os.chdir("C:\\Users\\aldwi\\OneDrive\\Desktop\\thesis\\notebook") #Set working directory
print(os.getcwd()) #Check new working directory
# Out:
# C:\Users\aldwi\0ADC_THESIS
# C:\Users\aldwi\OneDrive\Desktop\thesis\notebook

# %%
PIDD.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThick  Insulin   BMI  Pedigree  \
# 0            6      148             72         35        0  33.6     0.627
# 1            1       85             66         29        0  26.6     0.351
# 2            8      183             64          0        0  23.3     0.672
# 3            1       89             66         23       94  28.1     0.167
# 4            0      137             40         35      168  43.1     2.288
#
#    Age  Outcome
# 0   50        1
# 1   31        0
# 2   32        1
# 3   21        0
# 4   33        1

# %%
FGDD.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThick  Insulin   BMI  Pedigree  \
# 0            2      138             62         35        0  33.6     0.127
# 1            0       84             82         31      125  38.2     0.233
# 2            0      145              0          0        0  44.2     0.630
# 3            0      135             68         42      250  42.3     0.365
# 4            1      139             62         41      480  40.7     0.536
#
#    Age  Outcome
# 0   47        1
# 1   23        0
# 2   31        1
# 3   24        1
# 4   21        0

# %%
PIDD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pregnancies    768 non-null    int64
#  1   Glucose        768 non-null    int64
#  2   BloodPressure  768 non-null    int64
#  3   SkinThick      768 non-null    int64
#  4   Insulin        768 non-null    int64
#  5   BMI            768 non-null    float64
#  6   Pedigree       768 non-null    float64
#  7   Age            768 non-null    int64
#  8   Outcome        768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
FGDD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pregnancies    2000 non-null   int64
#  1   Glucose        2000 non-null   int64
#  2   BloodPressure  2000 non-null   int64
#  3   SkinThick      2000 non-null   int64
#  4   Insulin        2000 non-null   int64
#  5   BMI            2000 non-null   float64
#  6   Pedigree       2000 non-null   float64
#  7   Age            2000 non-null   int64
#  8   Outcome        2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("C:\\Users\\aldwi\\OneDrive\\Desktop\\thesis\\notebook\\data\\0PIDD_FGDD.csv")
data.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  Skin Thickness  Insulin   BMI  \
# 0            6    148.0            72.0            35.0      NaN  33.6
# 1            1     85.0            66.0            29.0      NaN  26.6
# 2            8    183.0            64.0             NaN      NaN  23.3
# 3            1     89.0            66.0            23.0     94.0  28.1
# 4            0    137.0            40.0            35.0    168.0  43.1
#
#    Pedigree  Age  Outcome
# 0     0.627   50        1
# 1     0.351   31        0
# 2     0.672   32        1
# 3     0.167   21        0
# 4     2.288   33        1

# %%
data = pd.read_csv("C:\\Users\\aldwi\\OneDrive\\Desktop\\thesis\\notebook\\data\\0PIDD_FGDD - Copy.csv")
data.head()

#R: df1 <- data.frame(x=unlist(df))
# Out:
#        Feature  Value  Outcome      Outcome2
# 0  Pregnancies    6.0        1      Diabetic
# 1  Pregnancies    1.0        0  Non-diabetic
# 2  Pregnancies    8.0        1      Diabetic
# 3  Pregnancies    1.0        0  Non-diabetic
# 4  Pregnancies    0.0        1      Diabetic

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin',
#        'BMI', 'Pedigree', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pregnancies     2768 non-null   int64
#  1   Glucose         2750 non-null   float64
#  2   Blood Pressure  2643 non-null   float64
#  3   Skin Thickness  1968 non-null   float64
#  4   Insulin         1438 non-null   float64
#  5   BMI             2729 non-null   float64
#  6   Pedigree        2768 non-null   float64
#  7   Age             2768 non-null   int64
#  8   Outcome         2768 non-null   int64
# dtypes: float64(6), int64(3)
# memory usage: 194.8 KB

# %%
data.describe()
# Out:
#        Pregnancies      Glucose  Blood Pressure  Skin Thickness      Insulin  \
# count  2768.000000  2750.000000     2643.000000     1968.000000  1438.000000
# mean      3.742775   121.895273       72.404086       29.289634   154.237830
# std       3.323801    30.600655       12.268576       10.711518   113.339578
# min       0.000000    44.000000       24.000000        7.000000    14.000000
# 25%       1.000000    99.000000       64.000000       22.000000    76.250000
# 50%       3.000000   117.000000       72.000000       29.000000   126.000000
# 75%       6.000000   141.000000       80.000000       36.000000   190.000000
# max      17.000000   199.000000      122.000000      110.000000   846.000000
#
#                BMI     Pedigree          Age      Outcome
# count  2729.000000  2768.000000  2768.000000  2768.000000
# mean     32.596665     0.471193    33.132225     0.343931
# std       7.154020     0.325669    11.777230     0.475104
# ...

# %% [markdown]
# # Distribution Analysis

# %%
import ptitprince as pt

col = ['Pregnancies', 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin', 'BMI', 'Pedigree', 'Age']
plt.figure(figsize=(10,25))



j=811
for i in col:
    plt.subplot(j)
    pt.RainCloud(data = data[data["Feature"]==i], x = 'Feature', y='Value', orient='h',move=0.25,
                palette='Blues', alpha=0.5)

    plt.xlabel(i)
    plt.ylabel(" ")
    plt.tight_layout()
        
    j = j+1

plt.savefig("raincloud_plots1.png")

# %%
help(plt.legend)
# Out:
# Help on function legend in module matplotlib.pyplot:
#
# legend(*args, **kwargs)
#     Place a legend on the Axes.
#
#     Call signatures::
#
#         legend()
#         legend(handles, labels)
#         legend(handles=handles)
#         legend(labels)
#
#     The call signatures correspond to the following different ways to use
#     this method:
#
#     **1. Automatic detection of elements to be shown in the legend**
#
#     The elements to be added to the legend are automatically determined,
#     when you do not pass in any extra arguments.
#
#     In this case, the labels are taken from the artist. You can specify
#     them either at artist creation or by calling the
#     :meth:`~.Artist.set_label` method on the artist::
#
#         ax.plot([1, 2, 3], label='Inline label')
#         ax.legend()
#
#     or::
#
#         line, = ax.plot([1, 2, 3])
#         line.set_label('Label via method')
#         ax.legend()
#
# ...

# %%
import ptitprince as pt

col1 = ['Pregnancies', 'Glucose', 'Blood Pressure', 'Skin Thickness','Insulin', 'BMI', 'Pedigree', 'Age']
plt.figure(figsize=(16,10))

j=421
for i in col1:
    plt.subplot(j)
    pt.RainCloud(data = data[data["Feature"]==i], x = 'Feature', y='Value', orient='h',move=0.25,
                palette='coolwarm', alpha=0.5,hue="Outcome",label=None, dodge=True)
    
    if j!=428:
        plt.legend("", loc='upper right',frameon=False)
    else:
        plt.legend(["Non-diabetic","Diabetic"], ncol=2, frameon=False, bbox_to_anchor=(1.02,-0.185))
        
    plt.xlabel(None)
    plt.ylabel(None)

    j=j+1

plt.tight_layout()

plt.savefig("raincloud_plotsss_coolwarm.jpg")

# %%
import ptitprince as pt

col = ['Pregnancies', 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin', 'BMI', 'Pedigree', 'Age']
plt.figure(figsize=(10,25))

j=811
for i in col:
    plt.subplot(j)
    pt.RainCloud(data = data[data["Feature"]==i], x = 'Feature', y='Value', orient='h',move=0.25,
                palette='vlag', alpha=0.5,hue="Outcome",label=None, dodge=True)
    
    if j!=811:
        plt.legend('', bbox_to_anchor=(1.05,0.95))
    else:
        plt.legend(["Non-diabetic","Diabetic"], ncol=2, frameon=False, bbox_to_anchor=(0.66,1.175))
        
    plt.xlabel(" ")
    plt.ylabel(" ")
    plt.tight_layout()
        
    j = j+1

plt.savefig("raincloud_plotss.jpg",dpi=1000)

# %%
import ptitprince as pt

col = ['Pregnancies', 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin', 'BMI', 'Pedigree', 'Age']
plt.figure(figsize=(12,25))

j=811
for i in col:
    plt.subplot(j)
    pt.RainCloud(data = data[data["Feature"]==i], x = 'Feature', y='Value', orient='h',move=0.25,
                palette='vlag', alpha=0.5,hue="Outcome",label=None)
    if j!=811:
        plt.legend('', bbox_to_anchor=(1.05,0.95))
    else:
        plt.legend(["Non-diabetic","Diabetic"], ncol=2, frameon=False, bbox_to_anchor=(0.66,1.175))
        
    plt.xlabel(i)
    plt.ylabel(" ")
    plt.tight_layout()
        
    j = j+1

plt.savefig("raincloud_plots.png")

# %%
def corrdot(*args, **kwargs):
    corr_r = args[0].corr(args[1], 'pearson')
    corr_text = f"{corr_r:2.2f}".replace("0.", ".")
    ax = plt.gca()
    ax.set_axis_off()
    marker_size = abs(corr_r) * 10000
    ax.scatter([.5], [.5], marker_size, [corr_r], alpha=0.6, cmap="coolwarm",
               vmin=-1, vmax=1, transform=ax.transAxes)
    font_size = abs(corr_r) * 40 + 5
    ax.annotate(corr_text, [.5, .5,],  xycoords="axes fraction",
                ha='center', va='center', fontsize=font_size)

data = data.drop(["Outcome"])

g = sns.PairGrid(data, aspect=1.4, diag_sharey=False)
g.map_lower(sns.regplot, lowess=True, ci=False, line_kws={'color': 'red'})
g.map_diag(sns.distplot, kde_kws={'color': 'black'})
g.map_upper(corrdot)
# Out:
# C:\Users\aldwi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\aldwi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
help(plt.legend)
# Out:
# Help on function legend in module matplotlib.pyplot:
#
# legend(*args, **kwargs)
#     Place a legend on the Axes.
#
#     Call signatures::
#
#         legend()
#         legend(handles, labels)
#         legend(handles=handles)
#         legend(labels)
#
#     The call signatures correspond to the following different ways to use
#     this method:
#
#     **1. Automatic detection of elements to be shown in the legend**
#
#     The elements to be added to the legend are automatically determined,
#     when you do not pass in any extra arguments.
#
#     In this case, the labels are taken from the artist. You can specify
#     them either at artist creation or by calling the
#     :meth:`~.Artist.set_label` method on the artist::
#
#         ax.plot([1, 2, 3], label='Inline label')
#         ax.legend()
#
#     or::
#
#         line, = ax.plot([1, 2, 3])
#         line.set_label('Label via method')
#         ax.legend()
#
# ...

# %%
plt.style.use('default')

g = sns.PairGrid(data=data, hue='Outcome',diag_sharey = False,palette="vlag")
g.map_lower(plt.scatter,alpha=0.6)
g.map_diag(sns.distplot)

plt.tight_layout()

plt.savefig("scattermatrix.png")
# Out:
# C:\Users\aldwi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\aldwi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(12,5))
g = sns.PairGrid(data=data,  hue='Outcome',diag_sharey = False,palette='vlag')
g.map_lower(plt.scatter,alpha=0.5)
g.map_diag(sns.distplot)
g.map_upper(sns.kdeplot, shade =True)
#plt.legend(["Non-diabetic","Diabetic"], ncol=2, frameon=False, bbox_to_anchor=(1,-1.3))
plt.tight_layout()
plt.savefig("scattermatrix_contour.jpg")
# Out:
# C:\Users\aldwi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\aldwi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
